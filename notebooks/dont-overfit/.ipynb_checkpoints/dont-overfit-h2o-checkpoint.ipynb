# %%
#!pip install h2o
import pandas as pd
import h2o
from h2o.automl import H2OAutoML
from benchmark_utils import timer

# %%
h2o.init()
X_train = h2o.import_file('dataset/train.csv',header=1)
X_test = h2o.import_file('dataset/test.csv',header=1)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O cluster uptime:         2 hours 58 mins
# H2O cluster timezone:       Etc/UTC
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.26.0.5
# H2O cluster version age:    1 month and 13 days
# H2O cluster name:           H2O_from_python_midas_86lhdg
# H2O cluster total nodes:    1
# H2O cluster free memory:    25.47 Gb
# H2O cluster total cores:    20
# H2O cluster allowed cores:  20
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python version:             3.7.4 final
# --------------------------  ------------------------------------------------------------------
# ...

# %%
X_train.head()
# Out:
# <table>
# <thead>
# ...

# %% [markdown]
# ## Treinamento

# %%
start_time = timer(None)

x = X_train.columns
y = "target"

X_train[y] = X_train[y].asfactor()

# (limited to 1 hour max runtime by default)
aml = H2OAutoML()
aml.train(x=x, y=y, training_frame=X_train)
time = timer(start_time)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
print(time)
# Out:
#  Time taken: 0 hours 31 minutes and 14.11 seconds.

# %%
# View the AutoML Leaderboard
lb = aml.leaderboard
lb.head(rows=lb.nrows)  # Print all rows instead of default (10 rows)
# Out:
# <table>
# <thead>
# <tr><th>model_id                                            </th><th style="text-align: right;">     auc</th><th style="text-align: right;">  logloss</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">     mse</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_AutoML_20191029_162612    </td><td style="text-align: right;">0.751181</td><td style="text-align: right;"> 0.565961</td><td style="text-align: right;">              0.373264</td><td style="text-align: right;">0.439015</td><td style="text-align: right;">0.192734</td></tr>
# <tr><td>DeepLearning_grid_1_AutoML_20191029_162612_model_22 </td><td style="text-align: right;">0.744792</td><td style="text-align: right;"> 3.03618 </td><td style="text-align: right;">              0.428472</td><td style="text-align: right;">0.543863</td><td style="text-align: right;">0.295787</td></tr>
# ...

# %%
# The leader model is stored here
aml.leader
# Out:
# Model Details
# ...
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_AutoML_20191029_162612
#
# No model summary for this model
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.005901775220803343
# RMSE: 0.07682301231273962
# LogLoss: 0.06813766373066883
# Null degrees of freedom: 249
# Residual degrees of freedom: 225
# Null deviance: 326.7090973968509
# Residual deviance: 34.06883186533442
# AIC: 84.06883186533442
# AUC: 1.0
# pr_auc: 0.9937499999999999
# Gini: 1.0
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.8284381532723729:
#              0      1 Error          Rate
# 0      0  90.0    0.0   0.0    (0.0/90.0)
# 1      1   0.0  160.0   0.0   (0.0/160.0)
# 2  Total  90.0  160.0   0.0   (0.0/250.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold      value    idx
# 0                        max f1   0.828438    1.00000  159.0
# ...

# %%
preds = aml.leader.predict(X_test)
print(preds)
# Out:
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th><th style="text-align: right;">       p0</th><th style="text-align: right;">       p1</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.627444 </td><td style="text-align: right;">0.372556 </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.739273 </td><td style="text-align: right;">0.260727 </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.874959 </td><td style="text-align: right;">0.125041 </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.0722252</td><td style="text-align: right;">0.927775 </td></tr>
# ...

# %%
h2o.save_model(aml.leader, path = "Dont-overfit_h2o")

# %%
print(time)
preds = list(preds['predict'])
id_test = X_test["id"]
# Out:
#  Time taken: 0 hours 31 minutes and 14.11 seconds.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-9c72fe8fb68a> in <module>
#       1 print(time)
# ----> 2 preds = list(preds['predict'])
#       3 id_test = X_test["id"]
#
# TypeError: list indices must be integers or slices, not str

# %%
submission = pd.DataFrame({
        "id": id_test,
        "target": preds
    })

submission.to_csv("../submit_files/dont_overfit_h2o_submission.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-2f2ef9630c35> in <module>
#       1 submission = pd.DataFrame({
# ----> 2         "id": id_test,
#       3         "target": preds
#       4     })
#       5
#
# NameError: name 'id_test' is not defined

# %%
#!pip install h2o
import pandas as pd
import h2o
from h2o.automl import H2OAutoML
from benchmark_utils import timer

# %%
h2o.init()
X_train = h2o.import_file('../datasets/santander-customer/train.csv',header=1)
X_test = h2o.import_file('../datasets/santander-customer/test.csv',header=1)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O cluster uptime:         21 mins 21 secs
# H2O cluster timezone:       Etc/UTC
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.26.0.5
# H2O cluster version age:    1 month and 15 days
# H2O cluster name:           H2O_from_python_midas_vwmyeg
# H2O cluster total nodes:    1
# H2O cluster free memory:    25.51 Gb
# H2O cluster total cores:    20
# H2O cluster allowed cores:  20
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python version:             3.7.4 final
# --------------------------  ------------------------------------------------------------------
# ...

# %%
X_train.head()
# Out:
# <table>
# <thead>
# ...

# %% [markdown]
# ## Treinamento

# %%
start_time = timer(None)

x = X_train.columns
y = "target"

X_train[y] = X_train[y].asfactor()

# (limited to 1 hour max runtime by default)
aml = H2OAutoML()
aml.train(x=x, y=y, training_frame=X_train)
time = timer(start_time)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
print(time)
# Out:
#  Time taken: 1 hours 0 minutes and 8.38 seconds.

# %%
# View the AutoML Leaderboard
lb = aml.leaderboard
lb.head(rows=lb.nrows)  # Print all rows instead of default (10 rows)
# Out:
# <table>
# <thead>
# <tr><th>model_id                                           </th><th style="text-align: right;">     auc</th><th style="text-align: right;">  logloss</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">      mse</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_BestOfFamily_AutoML_20191101_015515</td><td style="text-align: right;">0.882026</td><td style="text-align: right;"> 0.23172 </td><td style="text-align: right;">              0.247236</td><td style="text-align: right;">0.25359 </td><td style="text-align: right;">0.0643081</td></tr>
# <tr><td>XGBoost_1_AutoML_20191101_015515                   </td><td style="text-align: right;">0.88202 </td><td style="text-align: right;"> 0.225548</td><td style="text-align: right;">              0.247616</td><td style="text-align: right;">0.255807</td><td style="text-align: right;">0.0654372</td></tr>
# ...

# %%
# The leader model is stored here
aml.leader
# Out:
# Model Details
# ...
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_BestOfFamily_AutoML_20191101_015515
#
# No model summary for this model
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.007616638159109466
# RMSE: 0.08727335308735117
# LogLoss: 0.06274826074700429
# Null degrees of freedom: 199999
# Residual degrees of freedom: 199998
# Null deviance: 130463.31259090459
# Residual deviance: 25099.304298801715
# AIC: 25103.304298801715
# AUC: 0.9989124848038279
# pr_auc: 0.9550972371200357
# Gini: 0.9978249696076558
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.32857303980147873:
#                  0        1   Error                Rate
# 0      0  179554.0    348.0  0.0019    (348.0/179902.0)
# 1      1     696.0  19402.0  0.0346     (696.0/20098.0)
# 2  Total  180250.0  19750.0  0.0052   (1044.0/200000.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# ...

# %%
preds = aml.leader.predict(X_test)
print(preds)
# Out:
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th><th style="text-align: right;">      p0</th><th style="text-align: right;">       p1</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.9344  </td><td style="text-align: right;">0.0656002</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.914706</td><td style="text-align: right;">0.0852941</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.851697</td><td style="text-align: right;">0.148303 </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.945567</td><td style="text-align: right;">0.0544335</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.95164 </td><td style="text-align: right;">0.0483597</td></tr>
# ...

# %%
h2o.save_model(aml.leader, path = "santander_customer_h2o")
# Out:
# '/home/midas/disk2/sette/git/automl-notebooks-benchmark/porto_seguro/santander_customer_h2o/StackedEnsemble_BestOfFamily_AutoML_20191101_015515'

# %%
print(time)
preds = preds.as_data_frame().predict.values
id_test = X_test.as_data_frame().ID_code.values
# Out:
#  Time taken: 1 hours 0 minutes and 8.38 seconds.

# %%
submission = pd.DataFrame({
        "id": id_test,
        "target": preds
    })

submission.to_csv("../submit_files/santander_customer_h2o_submission.csv", index=False)
